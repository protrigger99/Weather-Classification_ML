# %%
# !pip install numpy pandas matplotlib seaborn missingno category-encoders scikit-learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

import warnings
warnings.filterwarnings('ignore')

# %%
train_df=pd.read_csv("train.csv")

# %%
train_df
# Out:
#               Date     Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2017-04-24  Navi-Mumbai     14.5     17.8      14.2          NaN
# 1       2013-10-11         Kota     24.6     39.5       0.0         12.0
# 2       2012-02-18     Vadodara     14.7     26.6       0.2          3.2
# 3       2012-02-18       Kanpur     18.3     26.6       0.0          NaN
# 4       2011-10-11     Srinagar     11.4     19.3       0.6          2.4
# ...            ...          ...      ...      ...       ...          ...
# 116363  2013-10-22  Navi-Mumbai     10.0     17.2       0.0          9.6
# 116364  2015-05-29       Ranchi      7.7     21.1       0.0          1.4
# 116365  2012-03-17      Dhanbad      7.6     21.7       0.0          6.0
# 116366  2014-06-23   Vijayawada      8.8     14.8       0.0          1.2
# 116367  2012-03-12     Jabalpur     15.8     40.6       0.0          9.2
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 0            NaN         NaN            NaN        NaN  ...        94.0
# 1            NaN          SE           31.0          N  ...        52.0
# 2            8.0         SSE           30.0         SW  ...        87.0
# 3            NaN          SE           28.0        WSW  ...        79.0
# 4            8.9           W           31.0         SW  ...        63.0
# ...          ...         ...            ...        ...  ...         ...
# 116363       8.8         NaN            NaN         SW  ...        58.0
# 116364       8.9           E           35.0         NE  ...        69.0
# 116365      11.2          SE           39.0         NE  ...        85.0
# 116366       2.0         NNE           56.0          N  ...        56.0
# 116367      11.3         WSW           31.0         NE  ...        28.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0               NaN       1024.1       1022.5       8.0       NaN     16.2
# 1              21.0       1011.8       1006.6       2.0       4.0     30.1
# 2              57.0       1018.2       1015.4       7.0       3.0     17.3
# 3              67.0       1017.0       1016.5       6.0       NaN     23.0
# 4              47.0       1018.6       1017.1       NaN       NaN     14.4
# ...             ...          ...          ...       ...       ...      ...
# 116363         58.0       1027.2       1025.7       7.0       1.0     13.8
# 116364         43.0       1026.7       1023.0       1.0       1.0     12.3
# 116365         42.0       1021.1       1019.6       2.0       2.0     13.7
# 116366         62.0        998.7        990.9       3.0       7.0     14.1
# 116367         28.0       1008.0       1005.1       2.0       2.0     30.1
#
#         Temp3pm  RainToday  Task
# 0           NaN        Yes   1.0
# 1          39.2         No   0.0
# 2          24.5         No   0.0
# 3          25.4         No   0.0
# 4          18.3         No   0.0
# ...         ...        ...   ...
# 116363     16.0         No   0.0
# 116364     20.1         No   0.0
# 116365     21.2         No   0.0
# 116366     13.6         No   0.0
# 116367     33.9         No   0.0
#
# [116368 rows x 23 columns]

# %%
test_df = pd.read_csv("test.csv")

# %%
# Splitting Date into seperate columns
train_df['Date'] = pd.to_datetime(train_df['Date'])

train_df['Year'] = train_df['Date'].dt.year
train_df['Month'] = train_df['Date'].dt.month
train_df['Day'] = train_df['Date'].dt.day

train_df.drop(['Date'], axis=1, inplace=True)

# %%
# counts stores counts of Locations where the Task is 1
counts = train_df[train_df['Task'] == 1]['Location'].value_counts().to_dict()
totCounts = train_df["Location"].value_counts()
counts
# Out:
# {'Nasik': 879,
#  'Kalyan-Dombivali': 765,
#  'Coimbatore': 762,
#  'Navi-Mumbai': 744,
#  'Aurangabad': 744,
#  'Surat': 743,
#  'Meerut': 729,
#  'Hyderabad': 700,
#  'Allahabad': 699,
#  'Raipur': 686,
#  'Sydney': 662,
#  'Bhopal': 653,
#  'Kolkata': 653,
#  'Vijayawada': 626,
#  'Visakhapatnam': 625,
#  'Vasai-Virar': 615,
#  'Jaipur': 606,
#  'Chennai': 593,
#  'Faridabad': 586,
#  'Rajkot': 566,
#  'Jodhpur': 561,
#  'Nagpore': 561,
#  'Srinagar': 554,
#  'Kanpur': 552,
#  'Patna': 518,
#  'Vadodara': 518,
#  'Ghaziabad': 510,
#  'Indore': 509,
#  'Jabalpur': 501,
#  'Dhanbad': 488,
#  'Penrith': 477,
#  'Mumbai': 473,
#  'Delhi': 471,
#  'Ranchi': 459,
#  'Thane': 453,
#  'Pimpri-Chinchwad': 450,
#  'Lucknow': 430,
#  'Pune': 430,
#  'Varanasi': 417,
#  'Howrah': 399,
#  'Gwalior': 373,
#  'Ahmedabad': 311,
#  'Bangalore': 299,
#  'Ludhiana': 257,
#  'Kota': 204,
#  'Agra': 200,
#  'Madurai': 194,
#  'Amritsar': 158,
#  'Guwahati': 94}

# %%
totCounts
# Out:
# Location
# Indore              2778
# Sydney              2623
# Rajkot              2587
# Vijayawada          2572
# Ghaziabad           2566
# Srinagar            2564
# Raipur              2560
# Jabalpur            2530
# Navi-Mumbai         2455
# Kalyan-Dombivali    2455
# Aurangabad          2451
# Thane               2446
# Patna               2444
# Chennai             2442
# Bhopal              2442
# Penrith             2440
# Jodhpur             2439
# Delhi               2439
# Visakhapatnam       2439
# Ranchi              2434
# Vasai-Virar         2431
# Nagpore             2430
# Varanasi            2428
# Nasik               2426
# Kolkata             2424
# Hyderabad           2422
# Mumbai              2421
# Madurai             2419
# Allahabad           2416
# Ahmedabad           2414
# Bangalore           2411
# Surat               2410
# Dhanbad             2410
# Vadodara            2401
# Pimpri-Chinchwad    2398
# Meerut              2395
# Lucknow             2393
# Amritsar            2391
# Coimbatore          2390
# Kanpur              2390
# Jaipur              2386
# Faridabad           2386
# Howrah              2382
# Ludhiana            2379
# Gwalior             2372
# Pune                2358
# Agra                1264
# Kota                1258
# Guwahati            1257
# Name: count, dtype: int64

# %%
msno.bar(train_df)
plt.savefig('NULL_msno_bar.png')

# %%
msno.matrix(train_df)
plt.savefig('NULL_msno_matrix.png')

# %%
train_df.hist(figsize=(20, 20), xrot=45)
plt.savefig('numerical_cols_hist.png')

# %%
import numpy as np
import matplotlib.pyplot as plt
_, axes = plt.subplots(5,4, figsize=(15, 15))
yes = train_df[train_df["Task"]==1]
no = train_df[train_df["Task"]==0]

ax = axes.ravel()
# flatten the 2D array
num_columns = train_df.select_dtypes(include=['number']).columns

count = 0
for i in num_columns:                   # for each of the 30 features
    bins = 80
    ax[count].hist(yes.loc[:,i], bins=bins, color='r', alpha=.5)
    ax[count].hist(no.loc[:,i], bins=bins, color='b', alpha=0.3)
    ax[count].set_title(i, fontsize=12)
    ax[count].legend(['yes','no'], loc='best', fontsize=8)
    count += 1

plt.tight_layout()
plt.savefig('carAndMeanoftask01.png')

# %%
categorical_columns = train_df.select_dtypes(include=['category', 'object']).columns

categorical_columns = categorical_columns.drop("Location")
# Set up a grid of subplots
fig, axes = plt.subplots(len(categorical_columns), 1, figsize=(12, 20))

# Iterate through categorical columns and create count plots
for i, column in enumerate(categorical_columns):
    sns.countplot(y=column, data=train_df, ax=axes[i])
    axes[i].set_title(f"Count Plot for {column}")

# Adjust layout and show the plots
plt.savefig('cat_cols_hist.png')

# %%
# Adding new column Counts, this contains the fraction of value for which Task of the Location is 1.
train_df["Counts"] = train_df["Location"].apply(lambda x: counts[x]/totCounts[x])

# %%
column_to_check = 'Task'
train_df = train_df.dropna(subset=[column_to_check])

# %%
train_df
# Out:
#            Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0       Navi-Mumbai     14.5     17.8      14.2          NaN       NaN
# 1              Kota     24.6     39.5       0.0         12.0       NaN
# 2          Vadodara     14.7     26.6       0.2          3.2       8.0
# 3            Kanpur     18.3     26.6       0.0          NaN       NaN
# 4          Srinagar     11.4     19.3       0.6          2.4       8.9
# ...             ...      ...      ...       ...          ...       ...
# 116363  Navi-Mumbai     10.0     17.2       0.0          9.6       8.8
# 116364       Ranchi      7.7     21.1       0.0          1.4       8.9
# 116365      Dhanbad      7.6     21.7       0.0          6.0      11.2
# 116366   Vijayawada      8.8     14.8       0.0          1.2       2.0
# 116367     Jabalpur     15.8     40.6       0.0          9.2      11.3
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Cloud9am  \
# 0              NaN            NaN        NaN        NaN  ...       8.0
# 1               SE           31.0          N         NW  ...       2.0
# 2              SSE           30.0         SW          S  ...       7.0
# 3               SE           28.0        WSW        SSE  ...       6.0
# 4                W           31.0         SW        SSW  ...       NaN
# ...            ...            ...        ...        ...  ...       ...
# 116363         NaN            NaN         SW        SSE  ...       7.0
# 116364           E           35.0         NE        SSE  ...       1.0
# 116365          SE           39.0         NE        ESE  ...       2.0
# 116366         NNE           56.0          N        NNE  ...       3.0
# 116367         WSW           31.0         NE        WSW  ...       2.0
#
#         Cloud3pm  Temp9am  Temp3pm  RainToday  Task  Year  Month  Day  \
# 0            NaN     16.2      NaN        Yes   1.0  2017      4   24
# 1            4.0     30.1     39.2         No   0.0  2013     10   11
# 2            3.0     17.3     24.5         No   0.0  2012      2   18
# 3            NaN     23.0     25.4         No   0.0  2012      2   18
# 4            NaN     14.4     18.3         No   0.0  2011     10   11
# ...          ...      ...      ...        ...   ...   ...    ...  ...
# 116363       1.0     13.8     16.0         No   0.0  2013     10   22
# 116364       1.0     12.3     20.1         No   0.0  2015      5   29
# 116365       2.0     13.7     21.2         No   0.0  2012      3   17
# 116366       7.0     14.1     13.6         No   0.0  2014      6   23
# 116367       2.0     30.1     33.9         No   0.0  2012      3   12
#
#           Counts
# 0       0.303055
# 1       0.162162
# 2       0.215743
# 3       0.230962
# 4       0.216069
# ...          ...
# 116363  0.303055
# 116364  0.188578
# 116365  0.202490
# 116366  0.243390
# 116367  0.198024
#
# [113761 rows x 26 columns]

# %%
null_value_percentages=(train_df.isna().sum()/train_df.shape[0])*100
null_value_percentages
# Out:
# Location          0.000000
# MinTemp           0.448308
# MaxTemp           0.229428
# Rainfall          0.981004
# Evaporation      42.880249
# Sunshine         47.754503
# WindGustDir       6.578704
# WindGustSpeed     6.539148
# WindDir9am        7.026134
# WindDir3pm        2.685455
# WindSpeed9am      0.951996
# WindSpeed3pm      1.871467
# Humidity9am       1.255263
# Humidity3pm       2.566785
# Pressure9am       9.883000
# Pressure3pm       9.869815
# Cloud9am         37.791510
# Cloud3pm         40.212375
# Temp9am           0.639059
# Temp3pm           1.941790
# RainToday         0.981004
# Task              0.000000
# Year              0.000000
# Month             0.000000
# Day               0.000000
# Counts            0.000000
# dtype: float64

# %%
# Dropping these columns as they contain nearly 40% null values
to_drop = ['Evaporation', 'Sunshine', 'Cloud9am','Cloud3pm',]
train_df.drop(to_drop,inplace=True,axis=1)
test_df.drop(to_drop,inplace=True,axis=1)

# %%
# Finding dataframe for each of the seasons
spring_df = train_df[train_df["Month"].isin([3, 4, 5])]
summer_df = train_df[train_df["Month"].isin([6,7,8])]
fall_df = train_df[train_df["Month"].isin([9,10,11])]
winter_df = train_df[train_df["Month"].isin([12,1,2])]

seasons = [spring_df,summer_df,fall_df,winter_df]
(spring_df)
# Out:
#            Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed  \
# 0       Navi-Mumbai     14.5     17.8      14.2         NaN            NaN
# 9          Varanasi     22.3     27.6      11.6          SE           43.0
# 18        Ghaziabad     12.3     22.1       0.6           N           63.0
# 23            Patna      7.2     19.2       0.4           E           52.0
# 26           Meerut     12.5     21.1       0.4          SE           37.0
# ...             ...      ...      ...       ...         ...            ...
# 116344   Vijayawada      5.5     16.3       0.0         NNW           28.0
# 116349      Dhanbad     13.0     24.6       0.4         ESE           41.0
# 116364       Ranchi      7.7     21.1       0.0           E           35.0
# 116365      Dhanbad      7.6     21.7       0.0          SE           39.0
# 116367     Jabalpur     15.8     40.6       0.0         WSW           31.0
#
#        WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  ...  Pressure9am  \
# 0             NaN        NaN           0.0           NaN  ...       1024.1
# 9             SSW        SSE          19.0          24.0  ...       1016.4
# 18              N          N          26.0          31.0  ...       1018.8
# 23             NW          E           6.0          33.0  ...       1025.2
# 26             SE        ESE          13.0          15.0  ...       1025.2
# ...           ...        ...           ...           ...  ...          ...
# 116344        NNW          E          17.0           4.0  ...       1021.2
# 116349         SE        ESE          20.0          19.0  ...       1021.8
# 116364         NE        SSE          15.0           9.0  ...       1026.7
# 116365         NE        ESE           6.0          17.0  ...       1021.1
# 116367         NE        WSW           9.0          13.0  ...       1008.0
#
#         Pressure3pm  Temp9am  Temp3pm  RainToday  Task  Year  Month  Day  \
# 0            1022.5     16.2      NaN        Yes   1.0  2017      4   24
# 9            1015.2     22.7     24.5        Yes   1.0  2016      4   14
# 18           1015.2     15.8     20.3         No   0.0  2014      5   26
# 23           1025.1     12.3     17.9         No   0.0  2011      3    5
# 26           1023.3     13.0     20.1         No   0.0  2014      3   25
# ...             ...      ...      ...        ...   ...   ...    ...  ...
# 116344       1017.7      8.1     14.8         No   0.0  2010      5   17
# 116349       1019.5     14.5     22.7         No   0.0  2011      3   14
# 116364       1023.0     12.3     20.1         No   0.0  2015      5   29
# 116365       1019.6     13.7     21.2         No   0.0  2012      3   17
# 116367       1005.1     30.1     33.9         No   0.0  2012      3   12
#
#           Counts
# 0       0.303055
# 9       0.171746
# 18      0.198753
# 23      0.211948
# 26      0.304384
# ...          ...
# 116344  0.243390
# 116349  0.202490
# 116364  0.188578
# 116365  0.202490
# 116367  0.198024
#
# [29885 rows x 22 columns]

# %%
# Filling the null values of the numerical colums with the median of the season it belongs to and
#  categorical columns with the mode of season it  belongs to
num_columns = train_df.select_dtypes(include=['number']).columns
for i in seasons:
    i[num_columns] = i[num_columns].fillna(i[num_columns].median())

    categorical_columns = i.select_dtypes(include=['object']).columns
    for column in categorical_columns:
        mode_value = i[column].mode().iloc[0]
        i[column].fillna(mode_value, inplace=True)

train_df
# Out:
#            Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed  \
# 0       Navi-Mumbai     14.5     17.8      14.2         NaN            NaN
# 1              Kota     24.6     39.5       0.0          SE           31.0
# 2          Vadodara     14.7     26.6       0.2         SSE           30.0
# 3            Kanpur     18.3     26.6       0.0          SE           28.0
# 4          Srinagar     11.4     19.3       0.6           W           31.0
# ...             ...      ...      ...       ...         ...            ...
# 116363  Navi-Mumbai     10.0     17.2       0.0         NaN            NaN
# 116364       Ranchi      7.7     21.1       0.0           E           35.0
# 116365      Dhanbad      7.6     21.7       0.0          SE           39.0
# 116366   Vijayawada      8.8     14.8       0.0         NNE           56.0
# 116367     Jabalpur     15.8     40.6       0.0         WSW           31.0
#
#        WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  ...  Pressure9am  \
# 0             NaN        NaN           0.0           NaN  ...       1024.1
# 1               N         NW           9.0          17.0  ...       1011.8
# 2              SW          S           7.0          11.0  ...       1018.2
# 3             WSW        SSE          11.0          22.0  ...       1017.0
# 4              SW        SSW          13.0          19.0  ...       1018.6
# ...           ...        ...           ...           ...  ...          ...
# 116363         SW        SSE           2.0          15.0  ...       1027.2
# 116364         NE        SSE          15.0           9.0  ...       1026.7
# 116365         NE        ESE           6.0          17.0  ...       1021.1
# 116366          N        NNE          19.0          28.0  ...        998.7
# 116367         NE        WSW           9.0          13.0  ...       1008.0
#
#         Pressure3pm  Temp9am  Temp3pm  RainToday  Task  Year  Month  Day  \
# 0            1022.5     16.2      NaN        Yes   1.0  2017      4   24
# 1            1006.6     30.1     39.2         No   0.0  2013     10   11
# 2            1015.4     17.3     24.5         No   0.0  2012      2   18
# 3            1016.5     23.0     25.4         No   0.0  2012      2   18
# 4            1017.1     14.4     18.3         No   0.0  2011     10   11
# ...             ...      ...      ...        ...   ...   ...    ...  ...
# 116363       1025.7     13.8     16.0         No   0.0  2013     10   22
# 116364       1023.0     12.3     20.1         No   0.0  2015      5   29
# 116365       1019.6     13.7     21.2         No   0.0  2012      3   17
# 116366        990.9     14.1     13.6         No   0.0  2014      6   23
# 116367       1005.1     30.1     33.9         No   0.0  2012      3   12
#
#           Counts
# 0       0.303055
# 1       0.162162
# 2       0.215743
# 3       0.230962
# 4       0.216069
# ...          ...
# 116363  0.303055
# 116364  0.188578
# 116365  0.202490
# 116366  0.243390
# 116367  0.198024
#
# [113761 rows x 22 columns]

# %%
train_df = pd.concat([seasons[0],seasons[1],seasons[2],seasons[3]])
train_df
# Out:
#            Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed  \
# 0       Navi-Mumbai     14.5     17.8      14.2          SE           35.0
# 9          Varanasi     22.3     27.6      11.6          SE           43.0
# 18        Ghaziabad     12.3     22.1       0.6           N           63.0
# 23            Patna      7.2     19.2       0.4           E           52.0
# 26           Meerut     12.5     21.1       0.4          SE           37.0
# ...             ...      ...      ...       ...         ...            ...
# 116348       Rajkot     21.5     31.3       0.0         ENE           22.0
# 116351     Vadodara     11.0     21.5       0.0           S           39.0
# 116353       Mumbai     20.1     33.0       0.0         ENE           61.0
# 116358      Gwalior      7.5     29.3       0.0         ENE           33.0
# 116359    Allahabad     15.8     34.0       0.0          SE           41.0
#
#        WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  ...  Pressure9am  \
# 0               E         SE           0.0          17.0  ...       1024.1
# 9             SSW        SSE          19.0          24.0  ...       1016.4
# 18              N          N          26.0          31.0  ...       1018.8
# 23             NW          E           6.0          33.0  ...       1025.2
# 26             SE        ESE          13.0          15.0  ...       1025.2
# ...           ...        ...           ...           ...  ...          ...
# 116348          S        ENE           4.0          11.0  ...       1017.3
# 116351        SSW          S          20.0          26.0  ...       1009.9
# 116353         SE        SSE          17.0          22.0  ...       1013.8
# 116358        ENE        ESE          19.0          19.0  ...       1013.4
# 116359         SE          S          11.0          20.0  ...       1015.0
#
#         Pressure3pm  Temp9am  Temp3pm  RainToday  Task  Year  Month  Day  \
# 0            1022.5     16.2     21.8        Yes   1.0  2017      4   24
# 9            1015.2     22.7     24.5        Yes   1.0  2016      4   14
# 18           1015.2     15.8     20.3         No   0.0  2014      5   26
# 23           1025.1     12.3     17.9         No   0.0  2011      3    5
# 26           1023.3     13.0     20.1         No   0.0  2014      3   25
# ...             ...      ...      ...        ...   ...   ...    ...  ...
# 116348       1013.4     27.4     30.3         No   0.0  2012      2   19
# 116351       1010.3     16.5     19.2         No   0.0  2011      1    5
# 116353       1010.6     26.7     32.5         No   1.0  2011      1    9
# 116358       1011.3     19.9     27.5         No   0.0  2016      2    4
# 116359       1012.3     23.5     30.5         No   0.0  2012      2   21
#
#           Counts
# 0       0.303055
# 9       0.171746
# 18      0.198753
# 23      0.211948
# 26      0.304384
# ...          ...
# 116348  0.218786
# 116351  0.215743
# 116353  0.195374
# 116358  0.157251
# 116359  0.289321
#
# [113761 rows x 22 columns]

# %%
train_df['Task'].value_counts()
sum = len(train_df)

# %%
# Shuffling the rows of train_df after concatenating the seasons 
train_df = train_df.sample(frac = 1)
train_df.reset_index(drop=True, inplace=True)

# %%
numerical_columns = train_df.select_dtypes(include=['number']).columns
column_to_remove = 'Task'

# Remove the specified column from numerical_columns
numerical_columns = [col for col in numerical_columns if col != column_to_remove]
num_plots = len(numerical_columns)
num_rows = num_plots // 5 + (num_plots % 5 > 0)  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, 5, figsize=(20, 4 * num_rows))

for i, column in enumerate(numerical_columns):
    row_index, col_index = divmod(i, 5)
    sns.boxplot(data=train_df[column], ax=axes[row_index, col_index])
    axes[row_index, col_index].set_title(f'Box Plot for {column}')

# Remove any empty subplots in the last row
if num_plots % 5 > 0:
    for j in range(num_plots % 5, 5):
        fig.delaxes(axes[num_rows - 1, j])

plt.tight_layout()
plt.savefig('outlier.png')

# %%
class outlierremoval:
    def __init__(self, col):
        q1 = col.quantile(0.25)
        q3 = col.quantile(0.75)
        inter_quartile_range=q3-q1
        self.upper_whisker=q3+inter_quartile_range*1.5
        self.lower_whisker=q1-inter_quartile_range*1.5

    def remove(self, row):
        if(row<=self.upper_whisker and row>=self.lower_whisker):
            return row
        elif row < self.lower_whisker:
            return self.lower_whisker
        else:
            return self.upper_whisker

# %% [markdown]
# Outlier Removal

# %%
for i in numerical_columns:
    if(i!='Task'):
        remover = outlierremoval(train_df[i])
        train_df[i]=train_df[i].apply(remover.remove)

# %%
# Converting the direction into angles 
dir = {'N': 0, 'NNE': 22.5, 'NE': 45.0, 'ENE': 67.5, 'E': 90.0, 'ESE': 112.5, 'SE': 135.0, 'SSE': 157.5, 'S':
180.0, 'SSW': 202.5, 'SW': 225.0, 'WSW': 247.5, 'W': 270.0, 'WNW': 292.5, 'NW': 315.0, 'NNW':
337.5}
dir_col = ['WindGustDir','WindDir9am','WindDir3pm']
for i in dir_col:
    train_df[i] = train_df[i].apply(lambda x: dir[x]).astype('float64')

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113761 entries, 0 to 113760
# Data columns (total 22 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Location       113761 non-null  object
#  1   MinTemp        113761 non-null  float64
#  2   MaxTemp        113761 non-null  float64
#  3   Rainfall       113761 non-null  float64
#  4   WindGustDir    113761 non-null  float64
#  5   WindGustSpeed  113761 non-null  float64
#  6   WindDir9am     113761 non-null  float64
#  7   WindDir3pm     113761 non-null  float64
#  8   WindSpeed9am   113761 non-null  float64
#  9   WindSpeed3pm   113761 non-null  float64
#  10  Humidity9am    113761 non-null  float64
#  11  Humidity3pm    113761 non-null  float64
#  12  Pressure9am    113761 non-null  float64
#  13  Pressure3pm    113761 non-null  float64
#  14  Temp9am        113761 non-null  float64
#  15  Temp3pm        113761 non-null  float64
#  16  RainToday      113761 non-null  object
#  17  Task           113761 non-null  float64
#  18  Year           113761 non-null  int64
#  19  Month          113761 non-null  int64
#  20  Day            113761 non-null  int64
#  21  Counts         113761 non-null  float64
# dtypes: float64(17), int64(3), object(2)
# memory usage: 19.1+ MB

# %% [markdown]
# Converting train_df to have equal number of Task 0's and 1's

# %%
category0 = train_df[train_df['Task'] == 0]
category1 = train_df[train_df['Task'] == 1]

# %%
diff = len(category0) - len(category1)
class_0_size = len(category0)
class_1_size = len(category1)
diff
# Out:
# 62847

# %%
# Here we decrease the number of 0s to bring it to half of total number of rows
num_rows_to_drop = int((class_0_size - sum/2) )

# Randomly sample the rows to drop
rows_to_drop = category0.sample(n=num_rows_to_drop, random_state=42)

# Create a new DataFrame excluding the sampled rows
category0 = category0.drop(rows_to_drop.index)

category0.reset_index(drop=True, inplace=True)
category0['Task'].value_counts()
# Out:
# Task
# 0.0    56881
# Name: count, dtype: int64

# %%
diff = len(category0) - len(category1)
class_0_size = len(category0)
class_1_size = len(category1)
diff
# Out:
# 31424

# %%
# Ḥere we increase the number of 1's to half of total number of rows
category1_oversampled = category1.sample(n=class_0_size, replace=True,random_state=42)

# Concatenate the oversampled class 1 with the original class 0
train_df = pd.concat([category0, category1_oversampled])
train_df['Task'].value_counts()
# Out:
# Task
# 0.0    56881
# 1.0    56881
# Name: count, dtype: int64

# %%
train_df.isna().sum()
# Out:
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# Task             0
# Year             0
# Month            0
# Day              0
# Counts           0
# dtype: int64

# %%
train_df = train_df.sample(frac = 1)
train_df.reset_index(drop=True, inplace=True)

# %%
train_df.isna().sum()
# Out:
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# Task             0
# Year             0
# Month            0
# Day              0
# Counts           0
# dtype: int64

# %%
X = train_df.drop('Task', axis=1)
Y = train_df['Task']

# %%
# !pip install category_encoders

# %%
import category_encoders as ce
encoder = ce.TargetEncoder(cols=categorical_columns)
X = encoder.fit_transform(X, Y)

# %%
train_df = X.copy()
train_df["Task"] = Y

# %%
plt.figure(figsize=(20,20))
sns.heatmap(train_df.corr(), cmap="YlGnBu", annot=True)
plt.savefig("corellation.png")

# %%
X
# Out:
#         Location  MinTemp  MaxTemp  Rainfall  WindGustDir  WindGustSpeed  \
# 0       0.543161     20.1     29.1       0.0     0.577584           54.0
# 1       0.561520      6.5      7.9       1.5     0.552237           43.0
# 2       0.576577     19.5     28.1       0.6     0.444993           61.0
# 3       0.482627     14.3     20.3       0.2     0.456066           56.0
# 4       0.457815     20.0     36.0       0.0     0.399168           43.0
# ...          ...      ...      ...       ...          ...            ...
# 113757  0.286247     19.1     34.4       0.0     0.577584           57.0
# 113758  0.547925     10.0     30.7       0.0     0.552237           44.0
# 113759  0.473019      3.6     17.9       0.0     0.584751           61.0
# 113760  0.540620     13.8     18.4       1.5     0.485972           37.0
# 113761  0.543161     18.0     21.0       0.6     0.498808           57.0
#
#         WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  ...  Humidity3pm  \
# 0         0.565333    0.564617          17.0          35.0  ...         63.0
# 1         0.555750    0.545744          15.0          20.0  ...         99.0
# 2         0.567623    0.451529          20.0          20.0  ...         68.0
# 3         0.426427    0.486501          33.0          35.0  ...         38.0
# 4         0.474939    0.436772          19.0          19.0  ...         28.0
# ...            ...         ...           ...           ...  ...          ...
# 113757    0.567623    0.589385          22.0          26.0  ...         30.0
# 113758    0.565333    0.589385          20.0          20.0  ...         31.0
# 113759    0.565333    0.588212           6.0          40.5  ...         41.0
# 113760    0.511734    0.486501          20.0          24.0  ...         93.0
# 113761    0.468870    0.462317          37.0          35.0  ...         78.0
#
#         Pressure9am  Pressure3pm  Temp9am  Temp3pm  RainToday  Year  Month  \
# 0            1003.4        998.4     24.1     27.4   0.390730  2016      3
# 1            1019.1       1016.7      7.7      6.1   0.748389  2015      4
# 2            1008.7       1005.7     21.9     25.4   0.390730  2014     12
# 3            1016.6       1016.4     15.7     17.8   0.390730  2009      2
# 4            1008.7       1002.4     26.4     33.8   0.390730  2012      1
# ...             ...          ...      ...      ...        ...   ...    ...
# 113757       1008.1       1004.7     24.4     33.5   0.390730  2012      3
# 113758       1011.8       1008.8     18.6     28.4   0.390730  2017      1
# 113759       1023.4       1018.7      8.3     16.8   0.390730  2009      8
# 113760       1007.6       1011.2     18.3     13.2   0.748389  2011     10
# 113761       1025.0       1024.7     19.8     19.0   0.390730  2017      4
#
#         Day    Counts
# 0        18  0.253982
# 1        24  0.267404
# 2         5  0.269389
# 3         9  0.215743
# 4        29  0.195374
# ...     ...       ...
# 113757   15  0.108029
# 113758   10  0.256253
# 113759    2  0.211948
# 113760   24  0.198753
# 113761    2  0.253982
#
# [113762 rows x 21 columns]

# %%
Y
# Out:
# 0         0.0
# 1         1.0
# 2         1.0
# 3         0.0
# 4         1.0
#          ...
# 113757    1.0
# 113758    0.0
# 113759    1.0
# 113760    1.0
# 113761    1.0
# Name: Task, Length: 113762, dtype: float64

# %%
# Here we use xgboost with validation set, to choose the best model
from sklearn.model_selection import train_test_split
import xgboost as xgb

X_train, X_valid, y_train, y_valid = train_test_split(X, Y, test_size=0.05, random_state=42)

dtrain = xgb.DMatrix(X_train, label=y_train)
dvalid = xgb.DMatrix(X_valid, label=y_valid)

params = {
    'objective': 'binary:logistic',
    'max_depth': 8,
    'learning_rate': 0.05,
    'eval_metric': 'logloss',
    'n_estimators':750,
    'min_child_weight':1,
    'subsample':0.6,
    'colsample_bytree': 1.0,
    'gamma':0.5,
    'reg_alpha':0.1,
    'reg_lambda':2
}

num_boost_round = 3000

evals = [(dvalid, 'eval')]
early_stopping_rounds = 10

model = xgb.train(params, dtrain, num_boost_round=num_boost_round, evals=evals, early_stopping_rounds=early_stopping_rounds)
# Out:
# [0]	eval-logloss:0.67505
# [1]	eval-logloss:0.65819
# [2]	eval-logloss:0.64300
# [3]	eval-logloss:0.62900
# [4]	eval-logloss:0.61615
# [5]	eval-logloss:0.60472
# [6]	eval-logloss:0.59382
# [7]	eval-logloss:0.58399
# [8]	eval-logloss:0.57478
# [9]	eval-logloss:0.56616
# [10]	eval-logloss:0.55805
# [11]	eval-logloss:0.55053
# [12]	eval-logloss:0.54378
# [13]	eval-logloss:0.53717
# [14]	eval-logloss:0.53105
# [15]	eval-logloss:0.52509
# [16]	eval-logloss:0.51978
# [17]	eval-logloss:0.51477
# [18]	eval-logloss:0.51002
# [19]	eval-logloss:0.50572
# [20]	eval-logloss:0.50147
# [21]	eval-logloss:0.49764
# [22]	eval-logloss:0.49411
# [23]	eval-logloss:0.49088
# [24]	eval-logloss:0.48754
# [25]	eval-logloss:0.48428
# [26]	eval-logloss:0.48130
# [27]	eval-logloss:0.47831
# [28]	eval-logloss:0.47566
# [29]	eval-logloss:0.47317
# [30]	eval-logloss:0.47101
# [31]	eval-logloss:0.46893
# [32]	eval-logloss:0.46650
# [33]	eval-logloss:0.46430
# [34]	eval-logloss:0.46251
# [35]	eval-logloss:0.46064
# [36]	eval-logloss:0.45889
# [37]	eval-logloss:0.45702
# [38]	eval-logloss:0.45551
# [39]	eval-logloss:0.45397
# [40]	eval-logloss:0.45251
# [41]	eval-logloss:0.45133
# [42]	eval-logloss:0.45009
# [43]	eval-logloss:0.44866
# [44]	eval-logloss:0.44746
# [45]	eval-logloss:0.44619
# [46]	eval-logloss:0.44506
# [47]	eval-logloss:0.44384
# [48]	eval-logloss:0.44288
# [49]	eval-logloss:0.44187
# [50]	eval-logloss:0.44072
# [51]	eval-logloss:0.43965
# [52]	eval-logloss:0.43832
# [53]	eval-logloss:0.43696
# [54]	eval-logloss:0.43600
# [55]	eval-logloss:0.43493
# [56]	eval-logloss:0.43371
# [57]	eval-logloss:0.43278
# [58]	eval-logloss:0.43190
# [59]	eval-logloss:0.43095
# [60]	eval-logloss:0.43020
# [61]	eval-logloss:0.42960
# [62]	eval-logloss:0.42887
# [63]	eval-logloss:0.42808
# [64]	eval-logloss:0.42720
# [65]	eval-logloss:0.42659
# [66]	eval-logloss:0.42536
# [67]	eval-logloss:0.42498
# [68]	eval-logloss:0.42413
# [69]	eval-logloss:0.42343
# [70]	eval-logloss:0.42293
# [71]	eval-logloss:0.42241
# [72]	eval-logloss:0.42189
# [73]	eval-logloss:0.42093
# [74]	eval-logloss:0.42031
# [75]	eval-logloss:0.41970
# [76]	eval-logloss:0.41886
# [77]	eval-logloss:0.41833
# [78]	eval-logloss:0.41778
# [79]	eval-logloss:0.41723
# [80]	eval-logloss:0.41660
# [81]	eval-logloss:0.41570
# [82]	eval-logloss:0.41501
# [83]	eval-logloss:0.41441
# [84]	eval-logloss:0.41375
# [85]	eval-logloss:0.41329
# [86]	eval-logloss:0.41259
# [87]	eval-logloss:0.41185
# [88]	eval-logloss:0.41094
# [89]	eval-logloss:0.41022
# [90]	eval-logloss:0.40948
# [91]	eval-logloss:0.40875
# [92]	eval-logloss:0.40818
# [93]	eval-logloss:0.40753
# [94]	eval-logloss:0.40696
# [95]	eval-logloss:0.40643
# [96]	eval-logloss:0.40581
# [97]	eval-logloss:0.40531
# [98]	eval-logloss:0.40453
# [99]	eval-logloss:0.40416
# [100]	eval-logloss:0.40341
# [101]	eval-logloss:0.40275
# [102]	eval-logloss:0.40229
# [103]	eval-logloss:0.40209
# [104]	eval-logloss:0.40146
# [105]	eval-logloss:0.40082
# [106]	eval-logloss:0.40027
# [107]	eval-logloss:0.39993
# [108]	eval-logloss:0.39962
# [109]	eval-logloss:0.39934
# [110]	eval-logloss:0.39902
# [111]	eval-logloss:0.39866
# [112]	eval-logloss:0.39829
# [113]	eval-logloss:0.39770
# [114]	eval-logloss:0.39715
# [115]	eval-logloss:0.39679
# [116]	eval-logloss:0.39655
# [117]	eval-logloss:0.39603
# [118]	eval-logloss:0.39511
# [119]	eval-logloss:0.39447
# [120]	eval-logloss:0.39412
# [121]	eval-logloss:0.39374
# [122]	eval-logloss:0.39343
# [123]	eval-logloss:0.39316
# [124]	eval-logloss:0.39262
# [125]	eval-logloss:0.39235
# [126]	eval-logloss:0.39182
# [127]	eval-logloss:0.39140
# [128]	eval-logloss:0.39099
# [129]	eval-logloss:0.39050
# [130]	eval-logloss:0.38992
# [131]	eval-logloss:0.38915
# [132]	eval-logloss:0.38898
# [133]	eval-logloss:0.38855
# [134]	eval-logloss:0.38811
# [135]	eval-logloss:0.38798
# [136]	eval-logloss:0.38734
# [137]	eval-logloss:0.38685
# [138]	eval-logloss:0.38645
# [139]	eval-logloss:0.38618
# [140]	eval-logloss:0.38567
# [141]	eval-logloss:0.38537
# [142]	eval-logloss:0.38495
# [143]	eval-logloss:0.38450
# [144]	eval-logloss:0.38420
# [145]	eval-logloss:0.38363
# [146]	eval-logloss:0.38326
# [147]	eval-logloss:0.38290
# [148]	eval-logloss:0.38263
# [149]	eval-logloss:0.38231
# [150]	eval-logloss:0.38160
# [151]	eval-logloss:0.38110
# [152]	eval-logloss:0.38062
# [153]	eval-logloss:0.38019
# [154]	eval-logloss:0.37983
# [155]	eval-logloss:0.37969
# [156]	eval-logloss:0.37953
# [157]	eval-logloss:0.37938
# [158]	eval-logloss:0.37925
# [159]	eval-logloss:0.37880
# [160]	eval-logloss:0.37842
# [161]	eval-logloss:0.37788
# [162]	eval-logloss:0.37739
# [163]	eval-logloss:0.37721
# [164]	eval-logloss:0.37683
# [165]	eval-logloss:0.37643
# [166]	eval-logloss:0.37584
# [167]	eval-logloss:0.37546
# [168]	eval-logloss:0.37513
# [169]	eval-logloss:0.37485
# [170]	eval-logloss:0.37436
# [171]	eval-logloss:0.37403
# [172]	eval-logloss:0.37380
# [173]	eval-logloss:0.37357
# [174]	eval-logloss:0.37311
# [175]	eval-logloss:0.37254
# [176]	eval-logloss:0.37214
# [177]	eval-logloss:0.37188
# [178]	eval-logloss:0.37153
# [179]	eval-logloss:0.37134
# [180]	eval-logloss:0.37091
# [181]	eval-logloss:0.37075
# [182]	eval-logloss:0.37022
# [183]	eval-logloss:0.36989
# [184]	eval-logloss:0.36959
# [185]	eval-logloss:0.36913
# [186]	eval-logloss:0.36894
# [187]	eval-logloss:0.36863
# [188]	eval-logloss:0.36820
# [189]	eval-logloss:0.36794
# [190]	eval-logloss:0.36751
# [191]	eval-logloss:0.36713
# [192]	eval-logloss:0.36692
# [193]	eval-logloss:0.36664
# [194]	eval-logloss:0.36627
# [195]	eval-logloss:0.36605
# [196]	eval-logloss:0.36574
# [197]	eval-logloss:0.36546
# [198]	eval-logloss:0.36524
# [199]	eval-logloss:0.36507
# [200]	eval-logloss:0.36469
# [201]	eval-logloss:0.36451
# [202]	eval-logloss:0.36430
# [203]	eval-logloss:0.36387
# [204]	eval-logloss:0.36367
# [205]	eval-logloss:0.36339
# [206]	eval-logloss:0.36322
# [207]	eval-logloss:0.36301
# [208]	eval-logloss:0.36269
# [209]	eval-logloss:0.36234
# [210]	eval-logloss:0.36212
# [211]	eval-logloss:0.36170
# [212]	eval-logloss:0.36131
# [213]	eval-logloss:0.36097
# [214]	eval-logloss:0.36076
# [215]	eval-logloss:0.36066
# [216]	eval-logloss:0.36017
# [217]	eval-logloss:0.36009
# [218]	eval-logloss:0.35983
# [219]	eval-logloss:0.35964
# [220]	eval-logloss:0.35942
# [221]	eval-logloss:0.35914
# [222]	eval-logloss:0.35869
# [223]	eval-logloss:0.35836
# [224]	eval-logloss:0.35810
# [225]	eval-logloss:0.35788
# [226]	eval-logloss:0.35759
# [227]	eval-logloss:0.35731
# [228]	eval-logloss:0.35693
# [229]	eval-logloss:0.35670
# [230]	eval-logloss:0.35631
# [231]	eval-logloss:0.35618
# [232]	eval-logloss:0.35583
# [233]	eval-logloss:0.35560
# [234]	eval-logloss:0.35552
# [235]	eval-logloss:0.35535
# [236]	eval-logloss:0.35505
# [237]	eval-logloss:0.35489
# [238]	eval-logloss:0.35428
# [239]	eval-logloss:0.35402
# [240]	eval-logloss:0.35367
# [241]	eval-logloss:0.35324
# [242]	eval-logloss:0.35285
# [243]	eval-logloss:0.35263
# [244]	eval-logloss:0.35219
# [245]	eval-logloss:0.35192
# [246]	eval-logloss:0.35173
# [247]	eval-logloss:0.35165
# [248]	eval-logloss:0.35135
# [249]	eval-logloss:0.35111
# [250]	eval-logloss:0.35077
# [251]	eval-logloss:0.35075
# [252]	eval-logloss:0.35050
# [253]	eval-logloss:0.35026
# [254]	eval-logloss:0.35013
# [255]	eval-logloss:0.34980
# [256]	eval-logloss:0.34964
# [257]	eval-logloss:0.34934
# [258]	eval-logloss:0.34908
# [259]	eval-logloss:0.34876
# [260]	eval-logloss:0.34852
# [261]	eval-logloss:0.34821
# [262]	eval-logloss:0.34797
# [263]	eval-logloss:0.34775
# [264]	eval-logloss:0.34745
# [265]	eval-logloss:0.34728
# [266]	eval-logloss:0.34703
# [267]	eval-logloss:0.34657
# [268]	eval-logloss:0.34642
# [269]	eval-logloss:0.34613
# [270]	eval-logloss:0.34599
# [271]	eval-logloss:0.34576
# [272]	eval-logloss:0.34565
# [273]	eval-logloss:0.34534
# [274]	eval-logloss:0.34510
# [275]	eval-logloss:0.34484
# [276]	eval-logloss:0.34453
# [277]	eval-logloss:0.34442
# [278]	eval-logloss:0.34424
# [279]	eval-logloss:0.34390
# [280]	eval-logloss:0.34372
# [281]	eval-logloss:0.34350
# [282]	eval-logloss:0.34309
# [283]	eval-logloss:0.34259
# [284]	eval-logloss:0.34242
# [285]	eval-logloss:0.34225
# [286]	eval-logloss:0.34212
# [287]	eval-logloss:0.34180
# [288]	eval-logloss:0.34164
# [289]	eval-logloss:0.34146
# [290]	eval-logloss:0.34115
# [291]	eval-logloss:0.34099
# [292]	eval-logloss:0.34072
# [293]	eval-logloss:0.34063
# [294]	eval-logloss:0.34044
# [295]	eval-logloss:0.34026
# [296]	eval-logloss:0.34008
# [297]	eval-logloss:0.33976
# [298]	eval-logloss:0.33941
# [299]	eval-logloss:0.33927
# [300]	eval-logloss:0.33908
# [301]	eval-logloss:0.33873
# [302]	eval-logloss:0.33846
# [303]	eval-logloss:0.33838
# [304]	eval-logloss:0.33828
# [305]	eval-logloss:0.33802
# [306]	eval-logloss:0.33791
# [307]	eval-logloss:0.33776
# [308]	eval-logloss:0.33746
# [309]	eval-logloss:0.33719
# [310]	eval-logloss:0.33688
# [311]	eval-logloss:0.33665
# [312]	eval-logloss:0.33648
# [313]	eval-logloss:0.33624
# [314]	eval-logloss:0.33592
# [315]	eval-logloss:0.33571
# [316]	eval-logloss:0.33550
# [317]	eval-logloss:0.33526
# [318]	eval-logloss:0.33497
# [319]	eval-logloss:0.33478
# [320]	eval-logloss:0.33449
# [321]	eval-logloss:0.33433
# [322]	eval-logloss:0.33414
# [323]	eval-logloss:0.33398
# [324]	eval-logloss:0.33395
# [325]	eval-logloss:0.33378
# [326]	eval-logloss:0.33365
# [327]	eval-logloss:0.33333
# [328]	eval-logloss:0.33300
# [329]	eval-logloss:0.33262
# [330]	eval-logloss:0.33251
# [331]	eval-logloss:0.33234
# [332]	eval-logloss:0.33208
# [333]	eval-logloss:0.33187
# [334]	eval-logloss:0.33167
# [335]	eval-logloss:0.33153
# [336]	eval-logloss:0.33137
# [337]	eval-logloss:0.33115
# [338]	eval-logloss:0.33090
# [339]	eval-logloss:0.33072
# [340]	eval-logloss:0.33048
# [341]	eval-logloss:0.33019
# [342]	eval-logloss:0.33006
# [343]	eval-logloss:0.32986
# [344]	eval-logloss:0.32965
# [345]	eval-logloss:0.32940
# [346]	eval-logloss:0.32896
# [347]	eval-logloss:0.32869
# [348]	eval-logloss:0.32844
# [349]	eval-logloss:0.32812
# [350]	eval-logloss:0.32800
# [351]	eval-logloss:0.32786
# [352]	eval-logloss:0.32764
# [353]	eval-logloss:0.32744
# [354]	eval-logloss:0.32734
# [355]	eval-logloss:0.32707
# [356]	eval-logloss:0.32686
# [357]	eval-logloss:0.32667
# [358]	eval-logloss:0.32653
# [359]	eval-logloss:0.32637
# [360]	eval-logloss:0.32634
# [361]	eval-logloss:0.32620
# [362]	eval-logloss:0.32613
# [363]	eval-logloss:0.32597
# [364]	eval-logloss:0.32566
# [365]	eval-logloss:0.32556
# [366]	eval-logloss:0.32534
# [458]	eval-logloss:0.31041
# [459]	eval-logloss:0.31021
# [460]	eval-logloss:0.31003
# [461]	eval-logloss:0.30990
# [462]	eval-logloss:0.30970
# [463]	eval-logloss:0.30959
# [464]	eval-logloss:0.30938
# [465]	eval-logloss:0.30917
# [466]	eval-logloss:0.30888
# [467]	eval-logloss:0.30857
# [468]	eval-logloss:0.30821
# [469]	eval-logloss:0.30810
# [470]	eval-logloss:0.30794
# [471]	eval-logloss:0.30778
# [472]	eval-logloss:0.30770
# [473]	eval-logloss:0.30753
# [474]	eval-logloss:0.30744
# [475]	eval-logloss:0.30736
# [476]	eval-logloss:0.30718
# [477]	eval-logloss:0.30695
# [478]	eval-logloss:0.30660
# [479]	eval-logloss:0.30630
# [480]	eval-logloss:0.30614
# [481]	eval-logloss:0.30601
# [482]	eval-logloss:0.30578
# [483]	eval-logloss:0.30554
# [484]	eval-logloss:0.30542
# [485]	eval-logloss:0.30520
# [486]	eval-logloss:0.30505
# [487]	eval-logloss:0.30488
# [488]	eval-logloss:0.30481
# [489]	eval-logloss:0.30471
# [490]	eval-logloss:0.30444
# [491]	eval-logloss:0.30422
# [492]	eval-logloss:0.30409
# [493]	eval-logloss:0.30388
# [494]	eval-logloss:0.30386
# [495]	eval-logloss:0.30379
# [496]	eval-logloss:0.30369
# [497]	eval-logloss:0.30356
# [498]	eval-logloss:0.30341
# [499]	eval-logloss:0.30321
# [500]	eval-logloss:0.30299
# [501]	eval-logloss:0.30270
# [502]	eval-logloss:0.30258
# [503]	eval-logloss:0.30244
# [504]	eval-logloss:0.30220
# [505]	eval-logloss:0.30209
# [506]	eval-logloss:0.30194
# [507]	eval-logloss:0.30185
# [508]	eval-logloss:0.30161
# [509]	eval-logloss:0.30155
# [510]	eval-logloss:0.30136
# [511]	eval-logloss:0.30115
# [512]	eval-logloss:0.30104
# [513]	eval-logloss:0.30082
# [514]	eval-logloss:0.30069
# [515]	eval-logloss:0.30059
# [516]	eval-logloss:0.30044
# [517]	eval-logloss:0.30030
# [518]	eval-logloss:0.30024
# [519]	eval-logloss:0.30021
# [520]	eval-logloss:0.30015
# [521]	eval-logloss:0.29996
# [522]	eval-logloss:0.29979
# [523]	eval-logloss:0.29962
# [524]	eval-logloss:0.29952
# [525]	eval-logloss:0.29945
# [526]	eval-logloss:0.29940
# [527]	eval-logloss:0.29923
# [528]	eval-logloss:0.29911
# [529]	eval-logloss:0.29893
# [530]	eval-logloss:0.29880
# [531]	eval-logloss:0.29871
# [532]	eval-logloss:0.29852
# [533]	eval-logloss:0.29827
# [534]	eval-logloss:0.29815
# [535]	eval-logloss:0.29792
# [536]	eval-logloss:0.29784
# [537]	eval-logloss:0.29775
# [538]	eval-logloss:0.29772
# [539]	eval-logloss:0.29765
# [540]	eval-logloss:0.29743
# [541]	eval-logloss:0.29727
# [542]	eval-logloss:0.29717
# [543]	eval-logloss:0.29701
# [544]	eval-logloss:0.29687
# [545]	eval-logloss:0.29677
# [546]	eval-logloss:0.29666
# [547]	eval-logloss:0.29651
# [548]	eval-logloss:0.29636
# [913]	eval-logloss:0.25724
# [914]	eval-logloss:0.25727
# [915]	eval-logloss:0.25715
# [916]	eval-logloss:0.25710
# [917]	eval-logloss:0.25696
# [918]	eval-logloss:0.25685
# [919]	eval-logloss:0.25677
# [920]	eval-logloss:0.25669
# [921]	eval-logloss:0.25666
# [922]	eval-logloss:0.25663
# [923]	eval-logloss:0.25654
# [924]	eval-logloss:0.25644
# [925]	eval-logloss:0.25637
# [926]	eval-logloss:0.25625
# [927]	eval-logloss:0.25620
# [928]	eval-logloss:0.25611
# [929]	eval-logloss:0.25605
# [930]	eval-logloss:0.25601
# [931]	eval-logloss:0.25594
# [932]	eval-logloss:0.25583
# [933]	eval-logloss:0.25575
# [934]	eval-logloss:0.25577
# [935]	eval-logloss:0.25579
# [936]	eval-logloss:0.25573
# [937]	eval-logloss:0.25563
# [938]	eval-logloss:0.25552
# [939]	eval-logloss:0.25546
# [940]	eval-logloss:0.25542
# [941]	eval-logloss:0.25539
# [942]	eval-logloss:0.25535
# [943]	eval-logloss:0.25517
# [944]	eval-logloss:0.25508
# [945]	eval-logloss:0.25492
# [946]	eval-logloss:0.25484
# [947]	eval-logloss:0.25473
# [948]	eval-logloss:0.25463
# [949]	eval-logloss:0.25450
# [950]	eval-logloss:0.25450
# [951]	eval-logloss:0.25444
# [952]	eval-logloss:0.25434
# [953]	eval-logloss:0.25417
# [954]	eval-logloss:0.25399
# [955]	eval-logloss:0.25395
# [956]	eval-logloss:0.25379
# [957]	eval-logloss:0.25371
# [958]	eval-logloss:0.25361
# [959]	eval-logloss:0.25349
# [960]	eval-logloss:0.25336
# [961]	eval-logloss:0.25338
# [962]	eval-logloss:0.25333
# [963]	eval-logloss:0.25320
# [964]	eval-logloss:0.25309
# [965]	eval-logloss:0.25302
# [966]	eval-logloss:0.25294
# [967]	eval-logloss:0.25284
# [968]	eval-logloss:0.25278
# [969]	eval-logloss:0.25269
# [970]	eval-logloss:0.25265
# [971]	eval-logloss:0.25254
# [972]	eval-logloss:0.25248
# [973]	eval-logloss:0.25234
# [974]	eval-logloss:0.25227
# [975]	eval-logloss:0.25214
# [976]	eval-logloss:0.25202
# [977]	eval-logloss:0.25194
# [978]	eval-logloss:0.25190
# [979]	eval-logloss:0.25187
# [980]	eval-logloss:0.25183
# [981]	eval-logloss:0.25168
# [982]	eval-logloss:0.25156
# [983]	eval-logloss:0.25138
# [984]	eval-logloss:0.25127
# [985]	eval-logloss:0.25122
# [986]	eval-logloss:0.25117
# [987]	eval-logloss:0.25111
# [988]	eval-logloss:0.25098
# [989]	eval-logloss:0.25089
# [990]	eval-logloss:0.25089
# [991]	eval-logloss:0.25079
# [992]	eval-logloss:0.25074
# [993]	eval-logloss:0.25063
# [994]	eval-logloss:0.25055
# [995]	eval-logloss:0.25049
# [996]	eval-logloss:0.25050
# [997]	eval-logloss:0.25046
# [998]	eval-logloss:0.25034
# [999]	eval-logloss:0.25032
# [1000]	eval-logloss:0.25026
# [1001]	eval-logloss:0.25022
# [1002]	eval-logloss:0.25012
# [1003]	eval-logloss:0.25007
# [1948]	eval-logloss:0.21129
# [1949]	eval-logloss:0.21126
# [1950]	eval-logloss:0.21125
# [1951]	eval-logloss:0.21124
# [1952]	eval-logloss:0.21125
# [1953]	eval-logloss:0.21125
# [1954]	eval-logloss:0.21127
# [1955]	eval-logloss:0.21127
# [1956]	eval-logloss:0.21127
# [1957]	eval-logloss:0.21129
# [1958]	eval-logloss:0.21130
# [1959]	eval-logloss:0.21130
# [1960]	eval-logloss:0.21128
# [1961]	eval-logloss:0.21128

# %%
test_df['Date'] = pd.to_datetime(test_df['Date'])

test_df['Year'] = test_df['Date'].dt.year
test_df['Month'] = test_df['Date'].dt.month
test_df['Day'] = test_df['Date'].dt.day

test_df.drop(['Date'], axis=1, inplace=True)

# %%
test_df["Counts"] = test_df["Location"].apply(lambda x: counts[x]/totCounts[x])

# %%
ids = test_df["ID"]
test_df.drop("ID", inplace=True, axis=1)

# %%
# Create DataFrames for each season
spring_df = test_df[test_df["Month"].isin([3, 4, 5])]
summer_df = test_df[test_df["Month"].isin([6,7,8])]
fall_df = test_df[test_df["Month"].isin([9,10,11])]
winter_df = test_df[test_df["Month"].isin([12,1,2])]

seasons = [spring_df,summer_df,fall_df,winter_df]
(spring_df)
# Out:
#          Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed  \
# 0      Aurangabad     15.0     18.9       4.2         NNW           54.0
# 1          Sydney     13.1     26.8       0.0         NaN            NaN
# 2            Pune     18.1     32.2       0.0          NE           30.0
# 6         Nagpore     17.7     22.3       NaN         SSE           54.0
# 7            Pune     18.4     25.7       2.6          NE           24.0
# ...           ...      ...      ...       ...         ...            ...
# 28422       Thane      5.0     23.0       0.0           N           19.0
# 28425    Guwahati     17.2     32.3       0.0           E           43.0
# 28426     Chennai     17.4     22.8      35.2         NaN            NaN
# 28430  Coimbatore     12.7     20.6       0.8         WNW           31.0
# 28431   Faridabad     20.2     26.4       0.0         NNE           39.0
#
#       WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  ...  Humidity3pm  \
# 0            NNW         NW          24.0          31.0  ...         64.0
# 1              W        WNW          22.0          15.0  ...         22.0
# 2            NaN         NE           0.0          17.0  ...         51.0
# 6            NaN          S           NaN          37.0  ...         80.0
# 7            NaN        NNE           0.0           2.0  ...         64.0
# ...          ...        ...           ...           ...  ...          ...
# 28422        NaN        NNW           0.0           6.0  ...         32.0
# 28425          E         SE          20.0          24.0  ...         18.0
# 28426         SE         SE          28.0          19.0  ...         92.0
# 28430        NNW        WSW          15.0          11.0  ...         83.0
# 28431        NNE        NNE          20.0           9.0  ...         37.0
#
#        Pressure9am  Pressure3pm  Temp9am  Temp3pm  RainToday  Year  Month  \
# 0           1005.2       1003.7     17.3     17.6        Yes  2012      4
# 1           1013.0       1009.0     16.9     25.9         No  2008      3
# 2           1019.2       1014.6     20.9     31.6         No  2013      3
# 6           1012.8       1014.3      NaN     17.0        NaN  2010      4
# 7           1026.5       1023.3     19.8     24.2        Yes  2014      3
# ...            ...          ...      ...      ...        ...   ...    ...
# 28422       1032.6       1028.3     13.2     21.9         No  2016      4
# 28425       1019.7       1015.8     24.3     32.0         No  2013      4
# 28426          NaN          NaN     21.4     20.8        Yes  2009      3
# 28430       1020.4       1020.4     15.9     19.2         No  2013      4
# 28431       1018.3       1016.6     21.8     25.2         No  2016      4
#
#        Day    Counts
# 0       22  0.303550
# 1       30  0.252383
# 2       27  0.182358
# 6       25  0.230864
# 7        4  0.182358
# ...    ...       ...
# 28422   25  0.185200
# 28425    8  0.074781
# 28426   31  0.242834
# 28430   23  0.318828
# 28431   28  0.245599
#
# [7512 rows x 21 columns]

# %%
# These functions return median and mode for the season test_df belongs to
def getMedian(row, idx, i):
    row = row.to_dict()
    x = row[i]
    month = row["Month"]

    if (not pd.isna(x)):
        return x
    if(month in [3,4,5]):
        return seasons[0].loc[: ,i].median()
    elif(month in [6,7,8]):
        return seasons[1].loc[:,i].median()
    elif(month in [9,10,11]):
        return seasons[2].loc[:,i].median()
    else:
        return seasons[3].loc[:,i].median()
    return

def getMode(row, idx, i):
    row = row.to_dict()
    x = row[i]
    month = row["Month"]
    if (not pd.isna(x)):
        return x
    if (not pd.isna(x)):
        return x
    if(month in [3,4,5]):
        return seasons[0].loc[: ,i].mode().iloc[0]
    elif(month in [6,7,8]):
        return seasons[1].loc[:,i].mode().iloc[0]
    elif(month in [9,10,11]):
        return seasons[2].loc[:,i].mode().iloc[0]
    else:
        return seasons[3].loc[:,i].mode().iloc[0]
    return

# %%
test_df
# Out:
#             Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed  \
# 0         Aurangabad     15.0     18.9       4.2         NNW           54.0
# 1             Sydney     13.1     26.8       0.0         NaN            NaN
# 2               Pune     18.1     32.2       0.0          NE           30.0
# 3             Sydney     13.9     19.6      14.0         SSW           50.0
# 4             Mumbai      0.6     11.9       0.2           W           22.0
# ...              ...      ...      ...       ...         ...            ...
# 28427  Visakhapatnam     10.8     19.7       0.0           N           43.0
# 28428         Sydney      8.7     18.2       0.0         NaN            NaN
# 28429        Chennai     14.5     25.2       0.0         NaN            NaN
# 28430     Coimbatore     12.7     20.6       0.8         WNW           31.0
# 28431      Faridabad     20.2     26.4       0.0         NNE           39.0
#
#       WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  ...  Humidity3pm  \
# 0            NNW         NW          24.0          31.0  ...         64.0
# 1              W        WNW          22.0          15.0  ...         22.0
# 2            NaN         NE           0.0          17.0  ...         51.0
# 3             SW          S          17.0          22.0  ...         64.0
# 4             SW         NW           2.0          11.0  ...         54.0
# ...          ...        ...           ...           ...  ...          ...
# 28427         NE        NNE          22.0          20.0  ...         68.0
# 28428        WNW        SSE          19.0          20.0  ...         62.0
# 28429         NW        NaN          19.0           NaN  ...          NaN
# 28430        NNW        WSW          15.0          11.0  ...         83.0
# 28431        NNE        NNE          20.0           9.0  ...         37.0
#
#        Pressure9am  Pressure3pm  Temp9am  Temp3pm  RainToday  Year  Month  \
# 0           1005.2       1003.7     17.3     17.6        Yes  2012      4
# 1           1013.0       1009.0     16.9     25.9         No  2008      3
# 2           1019.2       1014.6     20.9     31.6         No  2013      3
# 3              NaN       1018.4     15.5     19.1        Yes  2010     10
# 4           1024.3       1021.8      2.8     11.5         No  2010      6
# ...            ...          ...      ...      ...        ...   ...    ...
# 28427       1017.5       1013.7     16.3     17.2         No  2014      9
# 28428       1025.7       1022.3     12.5     16.1         No  2008      8
# 28429          NaN          NaN     22.5      NaN         No  2016     11
# 28430       1020.4       1020.4     15.9     19.2         No  2013      4
# 28431       1018.3       1016.6     21.8     25.2         No  2016      4
#
#        Day    Counts
# 0       22  0.303550
# 1       30  0.252383
# 2       27  0.182358
# 3       25  0.252383
# 4       27  0.195374
# ...    ...       ...
# 28427   24  0.256253
# 28428   29  0.252383
# 28429   26  0.242834
# 28430   23  0.318828
# 28431   28  0.245599
#
# [28432 rows x 21 columns]

# %%
# Filling null values of numerical columns with median of the season it belongs to and 
# with mode of the season it belongs to for categorical columns
num_columns = test_df.select_dtypes(include=['number']).columns
for i in num_columns:
    if(i!='Task'):
        test_df[i] = test_df.apply(lambda x: getMedian(x, x.name, i), axis=1)

categorical_columns = test_df.select_dtypes(include=['object']).columns
for i in categorical_columns:
    test_df[i] = test_df.apply(lambda x: getMode(x, x.index, i), axis=1)

# %%
dir = {'N': 0, 'NNE': 22.5, 'NE': 45.0, 'ENE': 67.5, 'E': 90.0, 'ESE': 112.5, 'SE': 135.0, 'SSE': 157.5, 'S':
180.0, 'SSW': 202.5, 'SW': 225.0, 'WSW': 247.5, 'W': 270.0, 'WNW': 292.5, 'NW': 315.0, 'NNW':
337.5}
dir_col = ['WindGustDir','WindDir9am','WindDir3pm']
for i in dir_col:
    test_df[i] = test_df[i].apply(lambda x: dir[x]).astype('float64')

# %%
test_df = pd.DataFrame(test_df)
test_df=encoder.transform(test_df)

# %%
train_df.columns
# Out:
# Index(['Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'WindGustDir',
#        'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'WindSpeed9am',
#        'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am',
#        'Pressure3pm', 'Temp9am', 'Temp3pm', 'RainToday', 'Year', 'Month',
#        'Day', 'Counts', 'Task'],
#       dtype='object')

# %%
test_df.columns
# Out:
# Index(['Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'WindGustDir',
#        'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'WindSpeed9am',
#        'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am',
#        'Pressure3pm', 'Temp9am', 'Temp3pm', 'RainToday', 'Year', 'Month',
#        'Day', 'Counts'],
#       dtype='object')

# %%
Y_pred = pd.to_numeric(model.predict(xgb.DMatrix(test_df)).round(), downcast ='signed')

dict = {'ID':[],
        'Task':[],
       }
for i in range(test_df.shape[0]):
    dict['ID'].append(ids.iloc[i])
    dict['Task'].append(int(Y_pred[i]))

ans = pd.DataFrame(dict)

ans.to_csv("subded3.csv", index=False)

# %%
Y_pred
# Out:
# array([1, 0, 0, ..., 0, 1, 0], dtype=int8)
